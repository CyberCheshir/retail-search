# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data/preprocessed/actual__preprocessed.csv')

# %%
df
# Out:
#                                        sap  employee   cashier  \
# 0     c7cfd542-9765-bd92-0240-ecb7fcd8452e  0.326531  0.342857
# 1     35373725-79f5-c17d-8c63-d347d20bf0a1  0.265306  0.057143
# 2     35e29d3a-bdca-a913-d54d-5da0fb69aa29  0.734694  0.200000
# 3     c022270f-3fbb-5c95-9ef9-8e2f9647979b  0.530612  0.228571
# 4     4a93a327-19ce-98e1-04fd-41964e8533b0  0.469388  0.257143
# ...                                    ...       ...       ...
# 1586  82372a51-ef9d-809e-2a47-06dc2a014fc6  0.244898  0.000000
# 1587  8362a450-709c-3b06-a8a9-a6155416bae2  0.244898  0.285714
# 1588  07726e5b-467c-7b5a-5de6-6c28f9250917  0.244898  0.285714
# 1589  93a9d0b1-5762-44d9-936d-74f4cb96415e  0.244898  0.285714
# 1590  7d2c1287-8db4-6cba-4634-6a83ea93675b  0.244898  0.285714
#
#              locality      area              coordinate  night_acceptance  \
# 0     Санкт-Петербург  0.338849  (59.938955, 30.315644)                 1
# ...

# %%
sns.pairplot(df[['employee','cashier','area','cash_desks','tobacco_shop','universal_assortment']],hue="universal_assortment")

# %% [markdown]
# Исходя из графиков что можно понять?
#
# у нас есть [гетероскедастические данные](https://en.wikipedia.org/wiki/Homoscedasticity_and_heteroscedasticity)
# для определения зависимости между универсальным ассортиментом и:
# - employee
# - cashier
# - area
